# %% [markdown]
# # 03 - Feature Engineering
#
# This notebook creates new features and encodes categorical variables.
#
# ## Objectives
# - Create Age and Years_at_Company features
# - Perform target encoding for State_Of_Origin
# - Encode categorical variables
# - Scale features for modeling

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '../src')

from feature_engineering import create_features, prepare_features

# %% [markdown]
# ## Continue feature engineering...
#
# See the complete analysis in `notebooks/final/Yakub_Promotion_Analysis_Enhanced.ipynb`
