# %% [markdown]
# # 01 - Data Exploration
#
# This notebook explores the Yakub Trading Group promotion dataset.
#
# ## Objectives
# - Load and inspect the dataset
# - Understand data structure and quality
# - Identify missing values and outliers
# - Explore distributions of key variables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
# Load data
df = pd.read_csv('../data/raw/Promotion Dataset.csv')

print(f"Dataset shape: {df.shape}")
print(f"\nColumns: {list(df.columns)}")

# %% [markdown]
# ## Continue exploration...
#
# See the complete analysis in `notebooks/final/Yakub_Promotion_Analysis_Enhanced.ipynb`
